# %%
import numpy as np
import librosa
import matplotlib.pyplot as plt
from IPython.display import Audio, display

# Load the audio file
audio_path = '../assets/audio/Sunflower.wav'
audio_signal, sample_rate = librosa.load(audio_path, sr=None)  # sr=None to use the original sampling rate

# Play the original audio using IPython.display.Audio
print("Playing original audio...")
display(Audio(data=audio_signal, rate=sample_rate))
# Out:
# Playing original audio...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Extract time and amplitude
duration = librosa.get_duration(y=audio_signal, sr=sample_rate)
time_points = np.linspace(0, duration, len(audio_signal))

# Plot the waveform
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time_points, audio_signal, label='Audio Signal')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.title('Waveform of Audio Signal')
plt.legend()

# Plot the frequency spectrum
plt.subplot(2, 1, 2)
frequencies = np.fft.fftfreq(len(audio_signal), d=1/sample_rate)
spectrum = np.abs(np.fft.fft(audio_signal))
plt.plot(frequencies[:len(frequencies)//2], spectrum[:len(spectrum)//2], label='Frequency Spectrum')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.title('Frequency Spectrum of Audio Signal')
plt.legend()

plt.tight_layout()
plt.show()

# Print audio properties
print(f"Sample Rate: {sample_rate} Hz")
print(f"Duration: {duration:.2f} seconds")
print(f"Number of Samples: {len(audio_signal)}")
print(f"First few amplitude values: {audio_signal[:10]}")
# Out:
# Sample Rate: 44100 Hz
# Duration: 5.00 seconds
# Number of Samples: 220500
# First few amplitude values: [-6.1035156e-05 -3.0517578e-05  3.0517578e-05  6.1035156e-05
#   3.0517578e-05  3.0517578e-05  3.0517578e-05  0.0000000e+00
#  -3.0517578e-05 -3.0517578e-05]
